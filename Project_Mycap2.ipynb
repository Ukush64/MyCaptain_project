# %% [markdown]
# ## Code to wrote down to marks scored in the last year of college and visualize the data on a bar plot

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x_axis = ["Business Communication", "Managerial Economics", "Business Accounting", "India’s Diversity & Business"]
y_axis = [67.50, 47, 41, 61.50]

plt.bar(x_axis, y_axis, )
plt.title('Marks scored')
plt.xlabel('Subjects')
plt.ylabel('Marks')
plt.show()
